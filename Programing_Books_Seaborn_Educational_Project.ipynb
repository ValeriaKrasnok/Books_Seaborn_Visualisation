# %%
#import all necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#download the dataframe
df_books = pd.read_csv('prog_book.csv')

# %%
#check first 5 rows of the dataframe
df_books.head()
# Out:
#    Rating Reviews                                         Book_title  \
# 0    4.17   3,829                              The Elements of Style
# 1    4.01   1,406      The Information: A History, a Theory, a Flood
# 2    3.33       0       Responsive Web Design Overview For Beginners
# 3    3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4    4.06   1,325                                   How Google Works
#
#                                          Description  Number_Of_Pages  \
# 0  This style manual offers practical advice on i...              105
# 1  James Gleick, the author of the best sellers C...              527
# 2  In Responsive Web Design Overview For Beginner...               50
# 3  If they were a hall of fame or shame for compu...              393
# 4  Both Eric Schmidt and Jonathan Rosenberg came ...              305
#
#              Type      Price
# 0       Hardcover   9.323529
# 1       Hardcover  11.000000
# 2  Kindle Edition  11.267647
# ...

# %%
#check last 5 rows of the dataframe
df_books.tail()
# Out:
#      Rating Reviews                                         Book_title  \
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# 266  Dave Eberly's 3D Game Engine Design was the fi...              752
# 267  Continuing in the eighth edition, An Introduct...             1040
# 268  Knuth's classic work has been widely acclaimed...              896
# 269  "The bible of all fundamental algorithms and t...             3168
# 270  Designed to help individual programmers develo...              789
#
#                       Type       Price
# 266              Hardcover  203.108823
# ...

# %%
#check all column names of the dataframe
df_books.columns
# Out:
# Index(['Rating', 'Reviews', 'Book_title', 'Description', 'Number_Of_Pages',
#        'Type', 'Price'],
#       dtype='object')

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating           271 non-null    float64
#  1   Reviews          271 non-null    object
#  2   Book_title       271 non-null    object
#  3   Description      271 non-null    object
#  4   Number_Of_Pages  271 non-null    int64
#  5   Type             271 non-null    object
#  6   Price            271 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.9+ KB

# %%
df_books.isnull().any()
# Out:
# Rating             False
# Reviews            False
# Book_title         False
# Description        False
# Number_Of_Pages    False
# Type               False
# Price              False
# dtype: bool

# %%
#check info about the first programming book
df_books.iloc[0]
# Out:
# Rating                                                          4.17
# Reviews                                                        3,829
# Book_title                                     The Elements of Style
# Description        This style manual offers practical advice on i...
# Number_Of_Pages                                                  105
# Type                                                       Hardcover
# Price                                                        9.32353
# Name: 0, dtype: object

# %%
#create a df for the first 5 prog books titles
df_books[['Book_title']].head()
# Out:
#                                           Book_title
# 0                              The Elements of Style
# 1      The Information: A History, a Theory, a Flood
# 2       Responsive Web Design Overview For Beginners
# 3  Ghost in the Wires: My Adventures as the World...
# 4                                   How Google Works

# %%
#create a df for the first 5 prog books titles and prices
df_books[['Book_title', 'Price']].head()
# Out:
#                                           Book_title      Price
# 0                              The Elements of Style   9.323529
# 1      The Information: A History, a Theory, a Flood  11.000000
# 2       Responsive Web Design Overview For Beginners  11.267647
# 3  Ghost in the Wires: My Adventures as the World...  12.873529
# 4                                   How Google Works  13.164706

# %%
#create a df for the book type paperback 
df_books[df_books['Type'] == 'Paperback']
# Out:
#      Rating Reviews                                         Book_title  \
# 5      3.84     117                                   The Meme Machine
# 9      4.62       0  ZX Spectrum Games Code Club: Twenty fun games ...
# 12     3.73      33                                           Ship It!
# 16     3.85      80  The Quark and the Jaguar: Adventures in the Si...
# 17     3.94     279  Linked: How Everything Is Connected to Everyth...
# ..      ...     ...                                                ...
# 246    4.37       0  A First Course in Logic: An Introduction to Mo...
# 250    4.10      31     Computer Architecture: A Quantitative Approach
# 253    4.11      56              Modern Operating Systems, 4th Edition
# 257    3.87      13  File Structures: An Object-Oriented Approach w...
# 267    3.94      22                An Introduction to Database Systems
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
#create a df with the book price less than 200
df_books[df_books['Price'] < 200]
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 261    3.82       0                            Game Programming Gems 6
# 262    4.08      56       Compilers: Principles, Techniques, and Tools
# 263    3.77       0                            Game Programming Gems 4
# 264    3.82       0                            Game Programming Gems 3
# 265    4.26       5  Numerical Recipes: The Art of Scientific Compu...
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
#create a df with a rating more than 4.5
df_books[df_books['Rating'] > 4.5]
# Out:
#      Rating Reviews                                         Book_title  \
# 9      4.62       0  ZX Spectrum Games Code Club: Twenty fun games ...
# 54     5.00       0                            Your First App: Node.js
# 103    4.54      52  The Elements of Computing Systems: Building a ...
# 114    4.67       1  Build Web Applications with Java: Learn every ...
# 131    4.72     362  Designing Data-Intensive Applications: The Big...
# 137    4.62      28  The Linux Programming Interface: A Linux and U...
# 146    4.54     171           Practical Object Oriented Design in Ruby
# 194    4.67      78  Fluent Python: Clear, Concise, and Effective P...
# 198    4.58      58                   CLR via C# (Developer Reference)
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
#
#                                            Description  Number_Of_Pages  \
# 9    This book is ideal for ZX Spectrum fans and be...              128
# ...

# %%
#create a df with a rating more than 4.5 and type hardcover 
df_books[(df_books['Rating'] > 4.5) & (df_books['Type'] == 'Hardcover')]
# Out:
#      Rating Reviews                                         Book_title  \
# 103    4.54      52  The Elements of Computing Systems: Building a ...
# 137    4.62      28  The Linux Programming Interface: A Linux and U...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
#
#                                            Description  Number_Of_Pages  \
# 103  This book is based on an abstraction-implement...              325
# 137  The Linux Programming Interface is the definit...             1506
# 269  "The bible of all fundamental algorithms and t...             3168
#
#           Type       Price
# 103  Hardcover   41.252941
# 137  Hardcover   46.358824
# 269  Hardcover  220.385294

# %%
#show descriptive statistics
df_books.describe()
# Out:
#            Rating  Number_Of_Pages       Price
# count  271.000000       271.000000  271.000000
# mean     4.067417       475.077491   54.541860
# std      0.290749       306.147492   35.711485
# min      3.000000        50.000000    9.323529
# 25%      3.915000       289.000000   30.751471
# 50%      4.100000       384.000000   46.317647
# 75%      4.250000       572.500000   67.854412
# max      5.000000      3168.000000  235.650000

# %%
#print the unique type's names
df_books['Type'].unique()
# Out:
# array(['Hardcover', 'Kindle Edition', 'Paperback', 'ebook',
#        'Unknown Binding', 'Boxed Set - Hardcover'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
#create a top 10 books list with a rating more than 4.3
df_top_books = df_books[df_books['Rating']>=4.3].head(10).sort_values(by = 'Rating', ascending = False)

# %%
df_top_books
# Out:
#     Rating Reviews                                         Book_title  \
# 54    5.00       0                            Your First App: Node.js
# 9     4.62       0  ZX Spectrum Games Code Club: Twenty fun games ...
# 67    4.40     547  Code: The Hidden Language of Computer Hardware...
# 81    4.39       3      Blueprints Visual Scripting for Unreal Engine
# 29    4.37       1                            Adventures in Minecraft
# 56    4.35     126  Python Crash Course: A Hands-On, Project-Based...
# 58    4.35      58       The Principles of Object-Oriented JavaScript
# 79    4.34      11  Practical SQL: A Beginner's Guide to Storytell...
# 41    4.33       0  Beginners Guide On PHP Programming: Quick And ...
# 31    4.32      39               Expert C Programming: Deep C Secrets
#
#                                           Description  Number_Of_Pages  \
# 54  A tutorial for real-world application developm...              317
# ...

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.bar(df_top_books['Book_title'], df_top_books['Rating'])
# Out:
# <BarContainer object of 10 artists>

# %%
#create a df with the first 15 books which have a price more than 100$
df_price_books = df_books[df_books['Price'] >=100].head(15).sort_values(by = 'Price', ascending = False)

# %%
df_price_books
# Out:
#      Rating Reviews                                         Book_title  \
# 264    3.82       0                            Game Programming Gems 3
# 263    3.77       0                            Game Programming Gems 4
# 262    4.08      56       Compilers: Principles, Techniques, and Tools
# 261    3.82       0                            Game Programming Gems 6
# 260    3.45       1  3D Game Engine Design: A Practical Approach to...
# 259    4.18     130         Artificial Intelligence: A Modern Approach
# 258    4.16      16  The C++ Standard Library: A Tutorial and Refer...
# 257    3.87      13  File Structures: An Object-Oriented Approach w...
# 256    4.13      14  Concepts, Techniques, and Models of Computer P...
# 255    3.67       2                                 Game Engine Gems 1
# 254    3.96      15                   Structured Computer Organization
# 252    4.11      56                           Modern Operating Systems
# ...

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.bar(df_price_books['Book_title'], df_price_books['Price'])
# Out:
# <BarContainer object of 15 artists>

# %%
#add lables for the last bar plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.bar(df_price_books['Book_title'], df_price_books['Price'])
plt.xlabel('Book_title')
plt.ylabel('Price')
plt.title('Prog books destribution by price')
# Out:
# Text(0.5, 1.0, 'Prog books destribution by price')

# %%
#create a horizontal bar plot
plt.figure(figsize = (12,5))
plt.xticks(rotation = 90)
plt.barh(df_price_books['Book_title'], df_price_books['Price'])
plt.xlabel('Book_title')
plt.ylabel('Price')
plt.title('Prog books destribution by price')
# Out:
# Text(0.5, 1.0, 'Prog books destribution by price')

# %%
#create a histogram
plt.figure(figsize = (12,6))
plt.hist(df_books['Price'], color = 'g')
# Out:
# (array([73., 93., 49., 35., 12.,  3.,  0.,  1.,  2.,  3.]),
#  array([  9.32352941,  31.95617647,  54.58882353,  77.22147059,
#          99.85411765, 122.48676471, 145.11941176, 167.75205882,
#         190.38470588, 213.01735294, 235.65      ]),
#  <a list of 10 Patch objects>)

# %%
#create a histogram
plt.figure(figsize = (12,6))
plt.hist(df_books['Rating'], color = 'r')
# Out:
# (array([ 3.,  6.,  7., 23., 53., 86., 68., 18.,  6.,  1.]),
#  array([3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. ]),
#  <a list of 10 Patch objects>)

# %%
#create a histogram
plt.figure(figsize = (12,6))
plt.hist(df_books['Number_Of_Pages'], color = 'y')
# Out:
# (array([123.,  99.,  33.,  14.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([  50. ,  361.8,  673.6,  985.4, 1297.2, 1609. , 1920.8, 2232.6,
#         2544.4, 2856.2, 3168. ]),
#  <a list of 10 Patch objects>)

# %%
#group books by type
df_type = df_books.groupby(['Type'])['Rating'].mean().sort_values(ascending = False).reset_index()

# %%
df_type
# Out:
#                     Type    Rating
# 0  Boxed Set - Hardcover  4.490000
# 1                  ebook  4.285714
# 2              Paperback  4.063846
# 3              Hardcover  4.059895
# 4         Kindle Edition  4.015000
# 5        Unknown Binding  3.990000

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.bar(df_type['Type'], df_type['Rating'])
plt.xlabel('Type')
plt.ylabel('Rating')
plt.title('Prog books destribution by type and rating')
# Out:
# Text(0.5, 1.0, 'Prog books destribution by type and rating')

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.barh(df_type['Type'], df_type['Rating'])
plt.xlabel('Type')
plt.ylabel('Rating')
plt.title('Prog books destribution by type and rating')
# Out:
# Text(0.5, 1.0, 'Prog books destribution by type and rating')

# %%
#convert object type to int and replace comma to dot
df_books['Reviews'] = df_books['Reviews'].astype(str).astype(int).replace(',', '')

# %%
df_books.head(2)
# Out:
#    Rating  Reviews                                     Book_title  \
# 0    4.17     3829                          The Elements of Style
# 1    4.01     1406  The Information: A History, a Theory, a Flood
#
#                                          Description  Number_Of_Pages  \
# 0  This style manual offers practical advice on i...              105
# 1  James Gleick, the author of the best sellers C...              527
#
#         Type      Price
# 0  Hardcover   9.323529
# 1  Hardcover  11.000000

# %%
#group books by type
df_reviews = df_books.groupby(['Type'])['Reviews'].sum().sort_values(ascending = False).reset_index()

# %%
df_reviews
# Out:
#                     Type  Reviews
# 0              Hardcover    29942
# 1              Paperback    18136
# 2         Kindle Edition     1565
# 3                  ebook      360
# 4        Unknown Binding      247
# 5  Boxed Set - Hardcover       36

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90)
plt.bar(df_reviews['Type'], df_reviews['Reviews'])
plt.xlabel('Type')
plt.ylabel('Reviews')
plt.title('Prog books destribution by type and reviews')
# Out:
# Text(0.5, 1.0, 'Prog books destribution by type and reviews')

# %%
explode = (0.1,0,0,0,0,0)
plt.figure(figsize=(10, 10))
plt.pie(df_reviews['Reviews'], labels = df_reviews['Type'],\
       explode = explode, shadow = True, autopct = '%1.1f%%') #autopct enables to display the percent value using Python string formatting
plt.show()

# %%
#create 3 groups of book types
df_other = df_reviews.tail(4)

# %%
df_other
# Out:
#                     Type  Reviews
# 2         Kindle Edition     1565
# 3                  ebook      360
# 4        Unknown Binding      247
# 5  Boxed Set - Hardcover       36

# %%
df_sum_other = df_other.sum(axis = 0, skipna = True).reset_index()

# %%
df_sum_other
# Out:
#      index                                                  0
# 0     Type  Kindle EditionebookUnknown BindingBoxed Set - ...
# 1  Reviews                                               2208

# %%
#drop 4 last books
df_new_reviews = df_reviews.drop(df_reviews.index[2:6])

# %%
df_new_reviews
# Out:
#         Type  Reviews
# 0  Hardcover    29942
# 1  Paperback    18136

# %%
df_new_reviews = df_new_reviews.append({'Type':'Other', 'Reviews': 2208},ignore_index=True)

# %%
df_new_reviews
# Out:
#         Type  Reviews
# 0  Hardcover    29942
# 1  Paperback    18136
# 2      Other     2208

# %%
explode = (0.1,0,0)
plt.figure(figsize=(10, 10))
plt.pie(df_new_reviews['Reviews'], labels = df_new_reviews['Type'],\
       explode = explode, shadow = True, autopct = '%1.1f%%') #autopct enables to display the percent value using Python string formatting
plt.show()

# %%
#create a subplot
plt.figure(figsize = (12,12))
plt.subplot(2,2,1)
plt.bar(df_reviews['Type'], df_reviews['Reviews'])


plt.subplot(2,2,2)
plt.pie(df_new_reviews['Reviews'], labels = df_new_reviews['Type'],\
       explode = explode, shadow = True, autopct = '%1.1f%%') #autopct enables to display the percent value using Python string formatting

plt.subplot(2,2,3)
plt.barh(df_type['Type'], df_type['Rating'])

plt.subplot(2,2,4)
plt.hist(df_books['Rating'], color = 'r')
# Out:
# (array([ 3.,  6.,  7., 23., 53., 86., 68., 18.,  6.,  1.]),
#  array([3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. ]),
#  <a list of 10 Patch objects>)

# %%
#create a countplot
plt.figure(figsize = (12,5))
plt.xticks(rotation = 90)
sns.countplot(x = 'Type', data = df_books)

# %%
#create a violinplot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Rating')
sns.violinplot(x='Type', y='Rating', data = df_books)

# %%
#create a violinplot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Number_Of_Pages')
sns.violinplot(x='Type', y='Number_Of_Pages', data = df_books)

# %%
#create a swarm plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Reviews')
sns.swarmplot(x='Type', y='Reviews', data = df_books)

# %%
#create a strip plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Rating')
sns.stripplot(x='Type', y='Rating', data = df_books)

# %%
#create a swarm plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Price')
sns.swarmplot(x='Type', y='Price', data = df_books)

# %%
#create a strip plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Rating')
sns.stripplot(x='Type', y='Number_Of_Pages', data = df_books)

# %%
#create a box plot

plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Rating')
sns.boxplot(x='Type', y='Rating', data = df_books)

# %%
#create a box plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Price')
sns.boxplot(x='Type', y='Price', data = df_books)

# %%
#create a horizontal bar plot
plt.figure(figsize = (12,6))
plt.xticks(rotation = 90, fontsize = 12)
plt.title('Type vs Price')
sns.barplot(y='Type', x = 'Price',  data = df_books)

# %%
#create a scatterplot
plt.figure(figsize = (12,6))
plt.title('Price vs Reviews')
sns.scatterplot(x = 'Price', y = 'Reviews', data = df_books)

# %%
#create a scatterplot
plt.figure(figsize = (12,6))
plt.title('Number of pages vs Price')
sns.scatterplot(x = 'Number_Of_Pages', y = 'Price', data = df_books)

# %%
#create a scatterplot
plt.figure(figsize = (12,6))
plt.title('Number of pages vs Reviews')
sns.scatterplot(x = 'Number_Of_Pages', y = 'Reviews', data = df_books)

# %%
#create a scatterplot with a hue
plt.figure(figsize = (12,6))
plt.title('Price vs Reviews')
sns.scatterplot(x = 'Price', y = 'Reviews', hue = 'Type', data = df_books)

# %%
#create a scatterplot
plt.figure(figsize = (12,6))
plt.title('Number of pages vs Reviews')
sns.scatterplot(x = 'Number_Of_Pages', y = 'Reviews',hue = 'Type', data = df_books)

# %%
sns.jointplot( x = 'Price', y = 'Reviews', color = 'g', data = df_books )

# %%
sns.jointplot( x = 'Number_Of_Pages', y = 'Reviews', color = 'r', data = df_books )

# %%
#create a Seaborn Hexagonal Bins
sns.jointplot( x = 'Price', y = 'Reviews', color = 'y',kind = 'hex', data = df_books )

# %%
#create a Kernel Density Estimation
sns.jointplot( x = 'Number_Of_Pages', y = 'Reviews', color = 'b',kind = 'kde', data = df_books )

# %%
#create a distribution plot
plt.figure(figsize = (16,5))
sns.distplot(df_books['Price'], color ='r')
sns.distplot(df_books['Reviews'], color = 'g')

# %%
#create a distribution plot without histograms
plt.figure(figsize = (16,5))
sns.distplot(df_books['Price'], color ='r', hist = False)
sns.distplot(df_books['Reviews'], color = 'g', hist = False)

# %%
#create a distribution plot without kde
plt.figure(figsize = (16,5))
sns.distplot(df_books['Price'], color ='r', kde = False)
sns.distplot(df_books['Reviews'], color = 'g', kde = False)

# %%
#create a pair plot
plt.figure(figsize = (12,6))
sns.pairplot(df_books)

# %%
#create a line plot
plt.figure(figsize = (12,6))
sns.lineplot(x = 'Price', y = 'Reviews', data = df_books)
sns.lineplot(x = 'Number_Of_Pages', y = 'Reviews', data = df_books)

# %%
#create a subplot
plt.figure(figsize = (12,12))

plt.subplot(2,2,1)
plt.title('Type vs Price')
sns.boxplot(x='Type', y='Price', data = df_books)

plt.subplot(2,2,2)
sns.scatterplot(x = 'Number_Of_Pages', y = 'Reviews',hue = 'Type', data = df_books)

plt.subplot(2,2,3)
sns.swarmplot(x='Type', y='Price', data = df_books)

plt.subplot(2,2,4)
sns.lineplot(x = 'Price', y = 'Reviews', data = df_books)
sns.lineplot(x = 'Number_Of_Pages', y = 'Reviews', data = df_books)

# %%
#create a corr table
corr_books = df_books.corr()

# %%
corr_books
# Out:
#                    Rating   Reviews  Number_Of_Pages     Price
# Rating           1.000000  0.045301         0.132189  0.046697
# Reviews          0.045301  1.000000        -0.131658 -0.254899
# Number_Of_Pages  0.132189 -0.131658         1.000000  0.636951
# Price            0.046697 -0.254899         0.636951  1.000000

# %%
#create a heatmap
plt.figure(figsize = (18,12))
sns.heatmap(corr_books, cmap = 'YlGnBu')

# %%
#add numbers to the heatmap
plt.figure(figsize = (18,12))
sns.heatmap(corr_books, cmap = 'coolwarm', annot = True)

# %%
plt.figure(figsize =(12,5))
sns.regplot(x = 'Price', y = 'Reviews', data = df_books,\
            marker = '*', color = 'r')

# %%
plt.figure(figsize =(12,15))
sns.lmplot(x = 'Price', y = 'Reviews', hue = 'Type', data = df_books)

# %%
g = sns.FacetGrid(df_books, height = 7, aspect = .5, hue = 'Type')
g.map(plt.hist,'Price')
g.add_legend()

# %%
type = ['Hardcover', 'Kindle Edition', 'Paperback', 'ebook','Unknown Binding', 'Boxed Set - Hardcover']

# %%
g = sns.FacetGrid(df_books, row="Type", row_order = type,
                  height=1.7, aspect=4,)
g.map(sns.lineplot, "Price","Reviews",color='r')

# %%
#create a pairgrid
p = sns.PairGrid(df_books, hue = 'Type')
p.map(plt.scatter)

# %%
#pip install wordcloud
#create a wordcloud
from wordcloud import WordCloud, STOPWORDS
c = ''.join(df_books['Book_title'].astype(str))
wordcloud = WordCloud(stopwords = STOPWORDS,\
                     background_color = 'white', width = 2400, height = 2000).generate(c)
plt.figure(figsize = (12,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
t = ''.join(df_books['Description'].astype(str))
wordcloud = WordCloud(stopwords = STOPWORDS,\
                     background_color = 'white', width = 2400, height = 2000).generate(t)
plt.figure(figsize = (12,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
